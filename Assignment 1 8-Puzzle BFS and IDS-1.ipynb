# %% [markdown]
# # Assignment 1, 8-Puzzle Programming

# %% [markdown]
# #### Your homework must be implemented in this Notebook file.
# #### You can add as many cells as you want. However, you are not allowed to touch the code below the line "=============".
# #### You need to implement the searching functions and the print result functions. The "print_result() function call after "====" line will print out the results in the format indicated in the Assignment description.
# #### For the searching functions, feel free to customize the return data types and parameter lists as long as the function name is as required.
#
# Write your name, netID and email here.
#
# ### Name: Nechar KC
# ### NetID: mt7388
# ### Email: nkhatrichatri@horizon.csueastbay.edu

# %%
# First, we will open the file, and then convert the numbers into a 3x3 Matrix.

textfile = open("Input8PuzzleCases.txt")
lines = textfile.readlines()
textfile.close()

puzzles = []

# Now lets clean the data and turn it into a 3x3 matrix.
for line in lines:
    line = line.strip()
    numbers = list(map(int, line.split(',')))

    # We create a row of 3 numbers, three times, creating a 3x3 matrix.
    puzzles.append([numbers[i:i+3] for i in range(0,9,3)])  

print(puzzles) # works as intended.

# We have successfully imported the text file and created a 3x3 matrix out of it.
# Out:
# [[[8, 7, 5], [4, 1, 2], [3, 0, 6]], [[7, 8, 6], [0, 2, 5], [1, 4, 3]], [[1, 0, 7], [5, 3, 6], [8, 4, 2]], [[3, 8, 4], [0, 1, 7], [5, 2, 6]], [[6, 1, 2], [7, 0, 8], [5, 4, 3]], [[2, 5, 3], [1, 4, 6], [8, 0, 7]], [[6, 8, 5], [3, 4, 7], [2, 1, 0]], [[2, 7, 8], [0, 1, 5], [4, 3, 6]], [[6, 5, 2], [1, 4, 8], [0, 7, 3]], [[0, 6, 1], [3, 4, 7], [8, 5, 2]], [[8, 5, 1], [7, 3, 2], [4, 6, 0]], [[4, 2, 7], [1, 5, 0], [8, 6, 3]], [[2, 7, 5], [8, 4, 6], [3, 0, 1]], [[6, 5, 8], [0, 2, 1], [7, 4, 3]], [[8, 5, 6], [2, 7, 0], [1, 4, 3]], [[2, 0, 7], [5, 1, 8], [6, 3, 4]], [[4, 2, 5], [7, 3, 1], [6, 8, 0]], [[7, 2, 0], [1, 3, 4], [6, 5, 8]], [[2, 6, 8], [7, 5, 0], [3, 1, 4]], [[1, 5, 0], [4, 7, 2], [6, 8, 3]], [[6, 5, 3], [8, 4, 7], [2, 1, 0]], [[8, 2, 4], [0, 3, 5], [6, 7, 1]], [[5, 4, 2], [8, 3, 6], [0, 1, 7]], [[4, 0, 5], [8, 7, 2], [3, 6, 1]], [[6, 0, 1], [4, 7, 3], [5, 2, 8]], [[4, 5, 3], [1, 0, 6], [7, 2, 8]], [[1, 0, 8], [5, 3, 7], [6, 4, 2]], [[4, 2, 6], [3, 7, 0], [8, 1, 5]], [[8, 4, 5], [7, 1, 3], [2, 6, 0]], [[1, 5, 7], [4, 0, 8], [2, 3, 6]], [[5, 7, 0], [6, 3, 8], [1, 2, 4]], [[2, 3, 1], [6, 7, 0], [5, 8, 4]], [[1, 6, 3], [0, 4, 5], [7, 2, 8]], [[8, 0, 3], [4, 6, 1], [2, 5, 7]], [[6, 2, 4], [8, 5, 7], [0, 1, 3]], [[4, 7, 0], [8, 2, 5], [3, 6, 1]], [[3, 6, 1], [7, 8, 0], [5, 2, 4]], [[1, 3, 4], [5, 2, 6], [8, 7, 0]], [[1, 0, 6], [2, 4, 5], [7, 8, 3]], [[0, 5, 4], [2, 6, 1], [8, 3, 7]], [[8, 4, 6], [3, 2, 7], [5, 0, 1]], [[3, 6, 8], [4, 2, 7], [1, 5, 0]], [[0, 6, 2], [7, 1, 5], [3, 4, 8]], [[3, 5, 6], [0, 1, 4], [2, 8, 7]], [[4, 0, 7], [3, 6, 2], [1, 5, 8]], [[1, 6, 4], [2, 8, 3], [0, 7, 5]], [[6, 0, 1], [3, 2, 7], [4, 5, 8]], [[3, 5, 0], [6, 7, 8], [2, 4, 1]], [[2, 0, 5], [4, 7, 3], [6, 8, 1]], [[7, 2, 0], [4, 1, 6], [5, 3, 8]], [[6, 4, 8], [1, 3, 7], [2, 5, 0]], [[8, 3, 6], [5, 0, 2], [1, 7, 4]], [[6, 2, 5], [8, 1, 3], [7, 4, 0]], [[4, 3, 2], [0, 5, 8], [1, 6, 7]], [[5, 1, 4], [0, 3, 7], [2, 8, 6]], [[3, 8, 5], [4, 1, 7], [0, 6, 2]], [[8, 4, 2], [6, 1, 0], [7, 3, 5]], [[5, 1, 6], [4, 2, 8], [7, 0, 3]], [[4, 6, 5], [3, 8, 7], [2, 0, 1]], [[1, 3, 2], [8, 6, 0], [4, 7, 5]], [[7, 8, 3], [2, 0, 1], [5, 4, 6]], [[5, 2, 4], [8, 1, 6], [3, 0, 7]], [[0, 4, 3], [1, 2, 5], [7, 6, 8]], [[3, 5, 0], [7, 4, 1], [2, 8, 6]], [[4, 7, 0], [5, 6, 1], [2, 3, 8]], [[3, 5, 1], [4, 6, 2], [0, 8, 7]], [[0, 8, 6], [4, 3, 7], [1, 2, 5]], [[7, 4, 0], [2, 5, 8], [6, 3, 1]], [[0, 3, 5], [8, 4, 2], [7, 6, 1]], [[2, 4, 6], [0, 3, 7], [5, 1, 8]], [[6, 4, 7], [1, 3, 2], [8, 5, 0]], [[1, 8, 5], [2, 0, 6], [3, 7, 4]], [[6, 8, 5], [2, 4, 3], [7, 1, 0]], [[2, 4, 3], [7, 1, 8], [6, 5, 0]], [[5, 2, 3], [0, 4, 7], [6, 1, 8]], [[3, 4, 5], [6, 7, 2], [0, 8, 1]], [[4, 6, 5], [2, 7, 8], [0, 3, 1]], [[5, 1, 8], [6, 4, 0], [7, 2, 3]], [[1, 2, 3], [5, 4, 0], [6, 8, 7]], [[2, 0, 6], [7, 8, 4], [5, 3, 1]], [[7, 2, 8], [4, 6, 0], [3, 1, 5]], [[7, 0, 6], [4, 1, 2], [8, 3, 5]], [[3, 5, 4], [7, 0, 6], [1, 2, 8]], [[8, 2, 7], [0, 6, 5], [4, 1, 3]], [[0, 5, 1], [4, 3, 2], [8, 7, 6]], [[4, 1, 8], [7, 5, 0], [3, 6, 2]], [[2, 3, 4], [6, 5, 8], [1, 0, 7]], [[8, 2, 6], [1, 0, 5], [7, 3, 4]], [[5, 4, 2], [0, 8, 1], [7, 3, 6]], [[4, 8, 2], [0, 5, 1], [7, 3, 6]], [[2, 1, 3], [0, 7, 8], [6, 5, 4]], [[8, 6, 4], [0, 3, 5], [2, 1, 7]], [[8, 3, 7], [4, 2, 6], [5, 0, 1]], [[6, 7, 2], [4, 1, 5], [0, 3, 8]], [[7, 4, 1], [5, 3, 2], [6, 8, 0]], [[8, 0, 2], [4, 5, 1], [3, 6, 7]], [[1, 2, 4], [5, 3, 6], [7, 0, 8]], [[6, 5, 1], [0, 8, 3], [4, 7, 2]], [[7, 5, 8], [3, 4, 1], [0, 6, 2]], [[6, 5, 7], [3, 8, 0], [4, 1, 2]]]

# %%
#The Goal State of the Matrix is:
goal_state = [[0,1,2],[3,4,5],[6,7,8]]

# We need to find the movable tile, 0.
def find_empty_tile(matrix):
    for i in range(3):
        for j in range(3):
            if matrix[i][j] == 0:
                return (i,j)
    return "Error"
matrix1 = puzzles[0] 

print(find_empty_tile(matrix1)) # works as intended.
# Out:
# (2, 1)

# %%
# Now we must find the possible moves for that 0 tile.

def find_possible_moves(matrix):
    row, col = find_empty_tile(matrix)
    legal_moves = []
    directions = [(-1, 0, "Up"), (0, 1, "Right"), (1, 0, "Down"), (0, -1, "Left")]

    for x, y, move in directions:
        new_row, new_col = row + x, col + y

        if 0 <= new_row < 3 and 0 <= new_col < 3:
            legal_moves.append((move, new_row, new_col))

    return legal_moves


print(find_possible_moves(matrix1)) # works as intended.
# Out:
# [('Up', 1, 1), ('Right', 2, 2), ('Left', 2, 0)]

# %%
# Making a temporary copy of the matrix so we dont affect the original. 

from copy import deepcopy

def apply_move(matrix, move):
    row, col = find_empty_tile(matrix)
    new_row, new_col = move[1], move[2]

    new_matrix = deepcopy(matrix)  # Ensure we don’t modify original

    # Swap tiles
    new_matrix[row][col], new_matrix[new_row][new_col] = new_matrix[new_row][new_col], new_matrix[row][col]

    return new_matrix

legalmoves = find_possible_moves(matrix1)
print(matrix1)
print(apply_move(matrix1, legalmoves[0]))
# Out:
# [[8, 7, 5], [4, 1, 2], [3, 0, 6]]
# [[8, 7, 5], [4, 0, 2], [3, 1, 6]]

# %%
#implementation of function "breadthFirstSearch" 

def breadth_first_search(start, goal):

    # first a queue to store starting state and moves.
    queue = [(start,[])]
    
    visited = set() # sets are faster lookup than lists.

    while queue:
        current_state, path = queue.pop(0)

        if current_state == goal:
            return path
        if str(current_state) in visited:
            continue # skip this iteration if already visited.
        visited.add(str(current_state))

        for move in find_possible_moves(current_state):
            new_state = apply_move(current_state, move)
            queue.append((new_state, path + [move]))
    return None

# testing
if breadth_first_search(matrix1, goal_state):
    print("Solution found") # properly printing!
# Out:
# Solution found

# %%
def depth_limited_search(matrix, goal, depth, path, visited):
    if matrix == goal:
        return path  # No need to change anything.

    if depth == 0:
        return None  # Stop at depth limit

    visited.add((str(matrix)))  # We'll store the matrices as strings for hashing in visited set instead of a list for performance.

    for move in find_possible_moves(matrix):
        new_state = apply_move(matrix, move)

        if str(new_state) not in visited:
            result = depth_limited_search(new_state, goal, depth - 1, path + [move], visited)
            if result:
                return result

    return None  # Meaning solution at this depth or no solution at all

# Lets create a solver for this.
def iddfs_solver(start, goal, max_depth=50):
    for depth in range(max_depth):
        print(f"Searching at depth: {depth}")  # Unnecessary line but useful for debugginng.
        result = depth_limited_search(start, goal, depth, [], set()) #I used a list first but it was super slow O(n) time, so a set is O(1) better.
 
        if result: # if we find a result, print and return.
            print("Solution found!")
            return result  

    print("No solution found within max depth")
    return None # no solution at max depth.

# testing
print(iddfs_solver(matrix1, goal_state, 50))
# Out:
# Searching at depth: 0
# Searching at depth: 1
# Searching at depth: 2
# Searching at depth: 3
# Searching at depth: 4
# Searching at depth: 5
# Searching at depth: 6
# Searching at depth: 7
# Searching at depth: 8
# Searching at depth: 9
# Searching at depth: 10
# Searching at depth: 11
# Searching at depth: 12
# Searching at depth: 13
# Searching at depth: 14
# Searching at depth: 15
# Searching at depth: 16
# Searching at depth: 17
# Searching at depth: 18
# Searching at depth: 19
# Searching at depth: 20
# Searching at depth: 21
# Searching at depth: 22
# Searching at depth: 23
# Searching at depth: 24
# Searching at depth: 25
# Searching at depth: 26
# Searching at depth: 27
# Searching at depth: 28
# Searching at depth: 29
# Searching at depth: 30
# Searching at depth: 31
# Searching at depth: 32
# Searching at depth: 33
# Searching at depth: 34
# Searching at depth: 35
# Searching at depth: 36
# Searching at depth: 37
# Searching at depth: 38
# Searching at depth: 39
# Solution found!
# [('Up', 1, 1), ('Up', 0, 1), ('Right', 0, 2), ('Down', 1, 2), ('Down', 2, 2), ('Left', 2, 1), ('Up', 1, 1), ('Up', 0, 1), ('Left', 0, 0), ('Down', 1, 0), ('Right', 1, 1), ('Up', 0, 1), ('Left', 0, 0), ('Down', 1, 0), ('Down', 2, 0), ('Right', 2, 1), ('Up', 1, 1), ('Up', 0, 1), ('Right', 0, 2), ('Down', 1, 2), ('Down', 2, 2), ('Left', 2, 1), ('Up', 1, 1), ('Up', 0, 1), ('Right', 0, 2), ('Down', 1, 2), ('Left', 1, 1), ('Up', 0, 1), ('Left', 0, 0), ('Down', 1, 0), ('Right', 1, 1), ('Up', 0, 1), ('Right', 0, 2), ('Down', 1, 2), ('Left', 1, 1), ('Down', 2, 1), ('Left', 2, 0), ('Up', 1, 0), ('Up', 0, 0)]

# %%
# Last step is to format and print the matrices.

testMatrix = puzzles[0] # The first matrix we will use to display the program.

# if goal, print goal, if not print XXX.
def print_matrix(matrix):

    for row in matrix: 
        print("".join(str(num) for num in row)) #printing the matrix in rows as strings.
    print()

# Formatting and generating solutions.
def print_result():
    BFS_solution = breadth_first_search(testMatrix, goal_state)
    if not BFS_solution:
        print("Solution not found")
        return

    current_state = testMatrix

    print("Solution of the first Scenario using BFS:\n")
    
    for row in testMatrix:
        print("".join(str(num) for num in row))
    print()
    
    for move in BFS_solution:
        current_state = apply_move(current_state, move)
        print("to\n")
        print_matrix(current_state)
    print()
    
    print("Solution of the first Scenario using IDS:\n")

    current_state = testMatrix # resetting the current_state so we dont rescramble a solved matrix.
    
    IDS_solution = iddfs_solver(testMatrix, goal_state, 50)
    if not IDS_solution:
        print("No solution for IDS")
        return
    for row in testMatrix:
        print("".join(str(num) for num in row))
    print()

    for move in IDS_solution:
        current_state = apply_move(current_state, move)
        print("to\n")
        print_matrix(current_state)
    print()

# %%
# EVERYTHING WORKS AS INTENDED, LOADING MIGHT TAKE 5-10 SECONDS! I TRIED TO OPTIMIZE IT AS MUCH AS I COULD.

# %% [markdown]
# ## You can insert as many cells as you want above
# ## You are not Allowed to modify the code below this line.
#
# # ============================================================

# %%
#you need to implement print_result function to print out the result according to the required format
print_result()
# Out:
# Solution of the first Scenario using BFS:
#
# 875
# 412
# 306
#
# to
#
# 875
# 402
# 316
#
# to
#
# 875
# 420
# 316
#
# to
#
# 870
# 425
# 316
#
# to
#
# 807
# 425
# 316
#
# to
#
# 827
# 405
# 316
#
# to
#
# 827
# 415
# 306
#
# to
#
# 827
# 415
# 360
#
# to
#
# 827
# 410
# 365
#
# to
#
# 820
# 417
# 365
#
# to
#
# 802
# 417
# 365
#
# to
#
# 812
# 407
# 365
#
# to
#
# 812
# 047
# 365
#
# to
#
# 012
# 847
# 365
#
# to
#
# 102
# 847
# 365
#
# to
#
# 142
# 807
# 365
#
# to
#
# 142
# 087
# 365
#
# to
#
# 142
# 387
# 065
#
# to
#
# 142
# 387
# 605
#
# to
#
# 142
# 307
# 685
#
# to
#
# 142
# 370
# 685
#
# to
#
# 142
# 375
# 680
#
# to
#
# 142
# 375
# 608
#
# to
#
# 142
# 305
# 678
#
# to
#
# 102
# 345
# 678
#
# to
#
# 012
# 345
# 678
#
#
# Solution of the first Scenario using IDS:
#
# Searching at depth: 0
# Searching at depth: 1
# Searching at depth: 2
# Searching at depth: 3
# Searching at depth: 4
# Searching at depth: 5
# Searching at depth: 6
# Searching at depth: 7
# Searching at depth: 8
# Searching at depth: 9
# Searching at depth: 10
# Searching at depth: 11
# Searching at depth: 12
# Searching at depth: 13
# Searching at depth: 14
# Searching at depth: 15
# Searching at depth: 16
# Searching at depth: 17
# Searching at depth: 18
# Searching at depth: 19
# Searching at depth: 20
# Searching at depth: 21
# Searching at depth: 22
# Searching at depth: 23
# Searching at depth: 24
# Searching at depth: 25
# Searching at depth: 26
# Searching at depth: 27
# Searching at depth: 28
# Searching at depth: 29
# Searching at depth: 30
# Searching at depth: 31
# Searching at depth: 32
# Searching at depth: 33
# Searching at depth: 34
# Searching at depth: 35
# Searching at depth: 36
# Searching at depth: 37
# Searching at depth: 38
# Searching at depth: 39
# Solution found!
# 875
# 412
# 306
#
# to
#
# 875
# 402
# 316
#
# to
#
# 805
# 472
# 316
#
# to
#
# 850
# 472
# 316
#
# to
#
# 852
# 470
# 316
#
# to
#
# 852
# 476
# 310
#
# to
#
# 852
# 476
# 301
#
# to
#
# 852
# 406
# 371
#
# to
#
# 802
# 456
# 371
#
# to
#
# 082
# 456
# 371
#
# to
#
# 482
# 056
# 371
#
# to
#
# 482
# 506
# 371
#
# to
#
# 402
# 586
# 371
#
# to
#
# 042
# 586
# 371
#
# to
#
# 542
# 086
# 371
#
# to
#
# 542
# 386
# 071
#
# to
#
# 542
# 386
# 701
#
# to
#
# 542
# 306
# 781
#
# to
#
# 502
# 346
# 781
#
# to
#
# 520
# 346
# 781
#
# to
#
# 526
# 340
# 781
#
# to
#
# 526
# 341
# 780
#
# to
#
# 526
# 341
# 708
#
# to
#
# 526
# 301
# 748
#
# to
#
# 506
# 321
# 748
#
# to
#
# 560
# 321
# 748
#
# to
#
# 561
# 320
# 748
#
# to
#
# 561
# 302
# 748
#
# to
#
# 501
# 362
# 748
#
# to
#
# 051
# 362
# 748
#
# to
#
# 351
# 062
# 748
#
# to
#
# 351
# 602
# 748
#
# to
#
# 301
# 652
# 748
#
# to
#
# 310
# 652
# 748
#
# to
#
# 312
# 650
# 748
#
# to
#
# 312
# 605
# 748
#
# to
#
# 312
# 645
# 708
#
# to
#
# 312
# 645
# 078
#
# to
#
# 312
# 045
# 678
#
# to
#
# 012
# 345
# 678

# %% [markdown]
# # The output format should be as follows. You only need to give one sample solution as an example.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# # Solution of the first Scenario:
# #### X X X
# #### X X X
# #### X X X
# #### to
# #### X X X
# #### X X X
# #### X X X
# #### to
# #### X X X
# #### X X X
# #### X X X
# #### to
# #### X X X
# #### X X X
# #### X X X
# #### to
# #### .
# #### .
# #### .
# #### 0 1 2
# #### 3 4 5
# #### 6 7 8
#
#                 Average_Steps    Average_Time
#  IDS
#
#  BFS
